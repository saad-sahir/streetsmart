# %% [markdown]
# # StreetSmart Dataframes

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import osmnx as ox
import glob, os
from datetime import datetime
import googlemaps
import matplotlib.pyplot as plt
import seaborn as sns


gmaps = googlemaps.Client(key="AIzaSyAcZ1jE7ZPYFR32EOTo4tWbXUU3hw09078")

# %% [markdown]
# ### Dataframe of historical crimes

# %%
#df = pd.concat(map(pd.read_csv, glob.glob(os.path.join('data/raw/history/', "*.csv"))))[['Month', 'Longitude', 'Latitude', 'Location', 'Crime type']].dropna(subset=['Latitude']).reset_index()
#df.to_csv('data/raw/history.csv')
#df = df.loc[(df['Latitude'] >= 51.3) & (df['Latitude'] <= 51.7)].loc[(df['Longitude'] >= -0.5) & (df['Longitude'] <= 0.2)].sort_values(['Latitude', 'Longitude'], ascending=[True,True]).reset_index()
#df.to_csv('data/raw/history_ldn.csv')
df = pd.read_csv('data/exports/crime_spots.csv')

# %% [markdown]
# #### Utility Function

# %%
def label_score(row):
    if row['Crime type'] == 'Anti-social behaviour':
        return 2
    if row['Crime type'] == 'Shoplifting':
        return 2
    if row['Crime type'] == 'Bicycle theft':
        return 5
    if row['Crime type'] == 'Public order':
        return 5
    if row['Crime type'] == 'Drugs':
        return 5
    if row['Crime type'] == 'Criminal damage and arson':
        return 8
    if row['Crime type'] == 'Vehicle crime':
        return 8
    if row['Crime type'] == 'Robbery':
        return 8
    if row['Crime type'] == 'Violence and sexual offences':
        return 8
    if row['Crime type'] == 'Theft from the person':
        return 8
    if row['Crime type'] == 'Burglary': 
        return 8
    if row['Crime type'] == 'Possession of weapons':
        return 8
    else:
        return 3
    
def weight_calculator(row):
    current_date = datetime.now().strftime('%Y-%m')
    current_year = int(current_date[:-3])
    current_month = int(current_date[-2:])
    
    target_date = row['Month']
    target_year = int(target_date[:-3])
    target_month = int(target_date[-2:])

    difference = ((current_year - target_year)*12) + (current_month - target_month)
    x = 10 - (difference/10)
    y = np.log(x**(1/2)+1)-0.4
    return y * row['Crime score']

df['Crime score'] = df.apply(lambda row: label_score(row), axis=1)
df['Crime score'] = round(df.apply(lambda row: weight_calculator(row), axis = 1),2)
df['Identifier'] = df['Longitude'] * df['Latitude'] + 444
df['Count'] = 1

# %% [markdown]
# #### Aggregating unique crime spots

# %%
ssdf=df.groupby(['Identifier']).agg({'Month':'first',
                                              'Longitude':'first',
                                              'Latitude':'first',
                                              'Crime score':'mean',
                                               'Count':'sum',
                                                }).reset_index()
ssdf['Crime score'] = ssdf['Crime score'].round(2)

# %% [markdown]
# #### Correlating count and crime score

# %%
ssdf['Average score'] = ssdf['Crime score']
ssdf['Crime score'] = round(ssdf['Crime score'] + ((5*ssdf['Count'])/(7*1095)), 2) ## 1095 = no. of days in 3 years

# %% [markdown]
# #### Final Dataframe View

# %%
ssdf.to_csv('data/exports/crime_spots.csv')
ssdf = pd.read_csv('data/exports/crime_spots.csv').drop(['Unnamed: 0'], axis=1)
ssdf
# Out:
#         Identifier    Month  Longitude   Latitude  Crime score  Count  \
# 0       418.193331  2022-10  -0.499726  51.641638         5.08      2
# 1       418.210909  2022-02  -0.499454  51.634567         6.17     13
# 2       418.216730  2022-08  -0.499871  51.579847         5.03      3
# 3       418.216880  2022-07  -0.499927  51.573769         7.11      3
# 4       418.217073  2022-06  -0.499279  51.640319         6.01      4
# ...            ...      ...        ...        ...          ...    ...
# 115245  454.306616  2021-06   0.199796  51.585696         5.33     22
# 115246  454.308765  2022-07   0.199915  51.565739         8.05      1
# 115247  454.309383  2021-06   0.199924  51.566512         5.19     21
# 115248  454.309791  2021-06   0.200000  51.548957         2.89     85
# 115249  454.325730  2022-07   0.199992  51.630715         5.57      4
#
#         Average score
# 0                5.08
# 1                6.16
# 2                5.03
# 3                7.11
# 4                6.01
# ...               ...
# 115245           5.32
# 115246           8.05
# 115247           5.18
# 115248           2.83
# 115249           5.57
#
# [115250 rows x 7 columns]

# %% [markdown]
# ### Dataframe of all CCTVs

# %%
cdf = pd.read_csv('data/cctv.csv')
lat_list, lng_list = [], []
for i in range(len(cdf['Location'])):
    location = gmaps.geocode(cdf['Location'][i]+', London')
    l_x, l_y = location[0]['geometry']['location']['lat'],location[0]['geometry']['location']['lng']
    lat_list.append(l_x), lng_list.append(l_y)
cdf['lat'], cdf['lng'] = lat_list, lng_list

# %% [markdown]
# #### Final Dataframe View

# %%
cdf.to_csv('data/exports/cctv.csv')
cdf
# Out:
#     Camera                                     Zone  \
# 0      TH2  North Finchley / Tally Ho High Road N12
# 1      TH3  North Finchley / Tally Ho High Road N12
# 2      TH4  North Finchley / Tally Ho High Road N12
# 3      TH5  North Finchley / Tally Ho High Road N12
# 4      TH7  North Finchley / Tally Ho High Road N12
# ..     ...                                      ...
# 119  TF141       Temple Fortune, Finchley Road NW11
# 120  TF142       Temple Fortune, Finchley Road NW11
# 121  TF143       Temple Fortune, Finchley Road NW11
# 122  TF144       Temple Fortune, Finchley Road NW11
# 123  TF145       Temple Fortune, Finchley Road NW11
#
#                                               Location        lat       lng
# 0         309 Ballards Lane junction with the Kingsway  51.612620 -0.178025
# 1                                        690 High Road  51.600944 -0.067554
# 2    Ballards Lane adjacent to Arts Depot opposite ...  51.612974 -0.176862
# 3    High Road Tally Ho Corner, opposite Stanhope Road  51.612794 -0.176740
# 4                        768 High Road The Bohemia PH.  51.615307 -0.176481
# ..                                                 ...        ...       ...
# 119         858 Finchley Road opposite Alberon Gardens  51.586557 -0.199475
# 120             Finchley Road opposite Hallswelle Road  51.561187 -0.197096
# 121     Finchley Road opposite Temple Fortune Mansions  51.582959 -0.199715
# 122            Finchley Road junction with Bridge Lane  51.589734 -0.199771
# 123        Finchley Road junction with Clifton Gardens  51.561187 -0.197096
#
# [124 rows x 5 columns]

# %% [markdown]
# ### Dataframe of Railway Stations

# %%
s_df = pd.concat(map(pd.read_csv, glob.glob(os.path.join('data/raw/station_crimes', "*.csv"))))[['Recorded Date', 'Station', 'Business Force Crime Group - Full']].reset_index()
del s_df['index']

# %% [markdown]
# #### Utility Functions

# %%
def label_score_station(row):
    if row['Business Force Crime Group - Full'] == '03A Criminal Damage': return 5
    if row['Business Force Crime Group - Full'] == '08A Burglary & Theft Railway': return 5
    if row['Business Force Crime Group - Full'] == '01A Violence': return 8
    if row['Business Force Crime Group - Full'] == '09A Public Order (Serious)': return 5
    if row['Business Force Crime Group - Full'] == '11A Drugs': return 5
    if row['Business Force Crime Group - Full'] == '06B Pedal Cycle': return 3
    if row['Business Force Crime Group - Full'] == '03B Graffiti': return 2
    if row['Business Force Crime Group - Full'] == '05A Theft of Passenger Property': return 4
    if row['Business Force Crime Group - Full'] == '02A Sex': return 7
    if row['Business Force Crime Group - Full'] == '04A Line of Route (Serious)': return 5
    if row['Business Force Crime Group - Full'] == '06A Motor Vehicle': return 4
    if row['Business Force Crime Group - Full'] == '12A Other (Serious)': return 6
    if row['Business Force Crime Group - Full'] == '01B Weapons': return 6
    if row['Business Force Crime Group - Full'] == '08B Theft Cable & Plant': return 5
    if row['Business Force Crime Group - Full'] == '10A Fraud (Serious)': return 5
    if row['Business Force Crime Group - Full'] == '07A Robbery': return 7

def weight_calculator(row):
    current_date = datetime.now().strftime('%Y-%m')
    current_year = int(current_date[:-3])
    current_month = int(current_date[-2:])
    
    target_date = row['Recorded Date']
    target_year = int(target_date[-4:])
    target_month = int(target_date[-2:])

    difference = ((current_year - target_year)*12) + (current_month - target_month)
    x = 10 - (difference/10)
    y = np.log(x**(1/2)+1)-0.4
    return y * row['score']

s_df['score'] = s_df.apply(lambda row: label_score_station(row), axis=1)
s_df['score'] = s_df.apply(lambda row: weight_calculator(row), axis = 1)
s_df['score'] = round(s_df['score'],2)

l = []
k = []
m = []
for i in range(len(s_df)):
    if s_df['Station'][i][-15:] == 'RAILWAY STATION':
        l.append(s_df['Station'][i])
        k.append(s_df['Recorded Date'][i])
        m.append(s_df['score'][i])

zipped = zip(l,k,m)
s_df = pd.DataFrame(zipped, columns = ['station','last recorded crime', 'score'])
s_df['count'] = 1

# %% [markdown]
# #### Aggregating unique crime spots

# %%
s_df=s_df.groupby(['station']).agg({'last recorded crime':'last',
                                              'score':'mean',
                                               'count':'sum',
                                                }).reset_index()
s_df['score'] = s_df['score'].round(2)

# %% [markdown]
# #### Adding lat,lng for each station

# %%
lat_list, lng_list = [], []

for i in range(len(s_df['station'])):
    location = gmaps.geocode(f"{s_df['station'][i]}, London")
    if location:
        l_x = location[0]['geometry']['location']['lat']
        l_y = location[0]['geometry']['location']['lng']
        lat_list.append(l_x)
        lng_list.append(l_y)
    else:
        location = gmaps.geocode(f"{s_df['station'][i][:-8]}, London")
        l_x = location[0]['geometry']['location']['lat']
        l_y = location[0]['geometry']['location']['lng']
        lat_list.append(l_x)
        lng_list.append(l_y)
    print(f"{s_df['station'][i]} appended ({i+1}/{len(s_df['station'])})")

s_df['lat'], s_df['lng'] = lat_list, lng_list
# Out:
# ABBEY WOOD RAILWAY STATION appended (1/2056)
# ABBEYWOOD MOD RAILWAY STATION appended (2/2056)
# ABER RAILWAY STATION appended (3/2056)
# ABERCYNON RAILWAY STATION appended (4/2056)
# ABERDARE RAILWAY STATION appended (5/2056)
# ABERDEEN RAILWAY STATION appended (6/2056)
# ABERDOUR RAILWAY STATION appended (7/2056)
# ABERDOVEY RAILWAY STATION appended (8/2056)
# ABERGAVENNY RAILWAY STATION appended (9/2056)
# ABERGELE AND PENSARN RAILWAY STATION appended (10/2056)
# ABERYSTWYTH RAILWAY STATION appended (11/2056)
# ACCRINGTON RAILWAY STATION appended (12/2056)
# ACTON CENTRAL RAILWAY STATION appended (13/2056)
# ACTON MAIN LINE RAILWAY STATION appended (14/2056)
# ADDERLEY PARK RAILWAY STATION appended (15/2056)
# ADDIEWELL RAILWAY STATION appended (16/2056)
# ADDLESTONE RAILWAY STATION appended (17/2056)
# ADISHAM RAILWAY STATION appended (18/2056)
# ADLINGTON RAILWAY STATION appended (19/2056)
# ADWICK RAILWAY STATION appended (20/2056)
# AIGBURTH RAILWAY STATION appended (21/2056)
# AINSDALE RAILWAY STATION appended (22/2056)
# AINTREE RAILWAY STATION appended (23/2056)
# AIRBLES RAILWAY STATION appended (24/2056)
# AIRDRIE RAILWAY STATION appended (25/2056)
# ALBANY PARK RAILWAY STATION appended (26/2056)
# ALBRIGHTON RAILWAY STATION appended (27/2056)
# ALDERLEY EDGE RAILWAY STATION appended (28/2056)
# ALDERMASTON RAILWAY STATION appended (29/2056)
# ALDERSHOT RAILWAY STATION appended (30/2056)
# ALDRINGTON RAILWAY STATION appended (31/2056)
# ALEXANDRA PALACE RAILWAY STATION appended (32/2056)
# ALEXANDRIA RAILWAY STATION appended (33/2056)
# ALFRETON RAILWAY STATION appended (34/2056)
# ALLENS WEST RAILWAY STATION appended (35/2056)
# ALLOA RAILWAY STATION appended (36/2056)
# ALRESFORD RAILWAY STATION appended (37/2056)
# ALSAGER RAILWAY STATION appended (38/2056)
# ALTHORNE RAILWAY STATION appended (39/2056)
# ALTON RAILWAY STATION appended (40/2056)
# ALVECHURCH RAILWAY STATION appended (41/2056)
# AMBERLEY RAILWAY STATION appended (42/2056)
# AMERSHAM RAILWAY STATION appended (43/2056)
# AMMANFORD RAILWAY STATION appended (44/2056)
# ANDERSTON RAILWAY STATION appended (45/2056)
# ANDOVER RAILWAY STATION appended (46/2056)
# ANERLEY RAILWAY STATION appended (47/2056)
# ANGEL ROAD RAILWAY STATION appended (48/2056)
# ANGMERING RAILWAY STATION appended (49/2056)
# ANNIESLAND RAILWAY STATION appended (50/2056)
# ANSDELL AND FAIRHAVEN RAILWAY STATION appended (51/2056)
# APPERLEY BRIDGE RAILWAY STATION appended (52/2056)
# APPLEBY RAILWAY STATION appended (53/2056)
# APPLEDORE RAILWAY STATION appended (54/2056)
# APPLEY BRIDGE RAILWAY STATION appended (55/2056)
# APSLEY RAILWAY STATION appended (56/2056)
# ARBROATH RAILWAY STATION appended (57/2056)
# ARDROSSAN HARBOUR RAILWAY STATION appended (58/2056)
# ARDROSSAN SOUTH BEACH RAILWAY STATION appended (59/2056)
# ARDROSSAN TOWN RAILWAY STATION appended (60/2056)
# ARDWICK RAILWAY STATION appended (61/2056)
# ARLESEY RAILWAY STATION appended (62/2056)
# ARMADALE RAILWAY STATION appended (63/2056)
# ARNSIDE RAILWAY STATION appended (64/2056)
# ARUNDEL RAILWAY STATION appended (65/2056)
# ASCOT RAILWAY STATION appended (66/2056)
# ASCOTT UNDER WYCHWOOD RAILWAY STATION appended (67/2056)
# ASH RAILWAY STATION appended (68/2056)
# ASH VALE RAILWAY STATION appended (69/2056)
# ASHBURYS RAILWAY STATION appended (70/2056)
# ASHCHURCH RAILWAY STATION appended (71/2056)
# ASHFIELD RAILWAY STATION appended (72/2056)
# ASHFORD (KENT) RAILWAY STATION appended (73/2056)
# ASHFORD (SURREY) RAILWAY STATION appended (74/2056)
# ASHFORD INTERNATIONAL RAILWAY STATION appended (75/2056)
# ASHLEY RAILWAY STATION appended (76/2056)
# ASHTEAD RAILWAY STATION appended (77/2056)
# ASHTON UNDER LYNE RAILWAY STATION appended (78/2056)
# ASHURST RAILWAY STATION appended (79/2056)
# ASHWELL AND MORDEN RAILWAY STATION appended (80/2056)
# ASKAM RAILWAY STATION appended (81/2056)
# ASTON RAILWAY STATION appended (82/2056)
# ATHERSTONE RAILWAY STATION appended (83/2056)
# ATHERTON CENTRAL RAILWAY STATION appended (84/2056)
# ATTENBOROUGH RAILWAY STATION appended (85/2056)
# ATTLEBOROUGH RAILWAY STATION appended (86/2056)
# AUDLEY END RAILWAY STATION appended (87/2056)
# AUGHTON PARK RAILWAY STATION appended (88/2056)
# AVONMOUTH RAILWAY STATION appended (89/2056)
# AXMINSTER RAILWAY STATION appended (90/2056)
# AYLESBURY RAILWAY STATION appended (91/2056)
# AYLESHAM RAILWAY STATION appended (92/2056)
# AYR RAILWAY STATION appended (93/2056)
# BACHE RAILWAY STATION appended (94/2056)
# BAGLAN RAILWAY STATION appended (95/2056)
# BAGSHOT RAILWAY STATION appended (96/2056)
# BAILDON RAILWAY STATION appended (97/2056)
# BAILLIESTON RAILWAY STATION appended (98/2056)
# BALCOMBE RAILWAY STATION appended (99/2056)
# BALDOCK RAILWAY STATION appended (100/2056)
# BALHAM RAILWAY STATION appended (101/2056)
# BALLOCH RAILWAY STATION appended (102/2056)
# BAMBER BRIDGE RAILWAY STATION appended (103/2056)
# BANBURY RAILWAY STATION appended (104/2056)
# BANGOR RAILWAY STATION appended (105/2056)
# BANK HALL RAILWAY STATION appended (106/2056)
# BANK TOP RAILWAY STATION appended (107/2056)
# BANSTEAD RAILWAY STATION appended (108/2056)
# BARASSIE RAILWAY STATION appended (109/2056)
# BARBICAN RAILWAY STATION appended (110/2056)
# BARDON MILL RAILWAY STATION appended (111/2056)
# BARE LANE RAILWAY STATION appended (112/2056)
# BARGEDDIE RAILWAY STATION appended (113/2056)
# BARGOED RAILWAY STATION appended (114/2056)
# BARMING RAILWAY STATION appended (115/2056)
# BARMOUTH RAILWAY STATION appended (116/2056)
# BARNEHURST RAILWAY STATION appended (117/2056)
# BARNES BRIDGE RAILWAY STATION appended (118/2056)
# BARNES RAILWAY STATION appended (119/2056)
# BARNETBY RAILWAY STATION appended (120/2056)
# BARNHAM RAILWAY STATION appended (121/2056)
# BARNHILL RAILWAY STATION appended (122/2056)
# BARNSLEY RAILWAY STATION appended (123/2056)
# BARNSTAPLE RAILWAY STATION appended (124/2056)
# BARNT GREEN RAILWAY STATION appended (125/2056)
# BARRHEAD RAILWAY STATION appended (126/2056)
# BARROW IN FURNESS RAILWAY STATION appended (127/2056)
# BARROW UPON SOAR RAILWAY STATION appended (128/2056)
# BARRY DOCKS RAILWAY STATION appended (129/2056)
# BARRY ISLAND RAILWAY STATION appended (130/2056)
# BARRY TOWN RAILWAY STATION appended (131/2056)
# BASILDON RAILWAY STATION appended (132/2056)
# BASINGSTOKE RAILWAY STATION appended (133/2056)
# BAT AND BALL RAILWAY STATION appended (134/2056)
# BATH SPA RAILWAY STATION appended (135/2056)
# BATHGATE RAILWAY STATION appended (136/2056)
# BATLEY RAILWAY STATION appended (137/2056)
# BATTERSEA PARK RAILWAY STATION appended (138/2056)
# BATTLE RAILWAY STATION appended (139/2056)
# BEACONSFIELD RAILWAY STATION appended (140/2056)
# BEARSDEN RAILWAY STATION appended (141/2056)
# BEARSTED RAILWAY STATION appended (142/2056)
# BEAULIEU ROAD RAILWAY STATION appended (143/2056)
# BEBINGTON RAILWAY STATION appended (144/2056)
# BECCLES RAILWAY STATION appended (145/2056)
# BECKENHAM HILL RAILWAY STATION appended (146/2056)
# BECKENHAM JUNCTION RAILWAY STATION appended (147/2056)
# BEDFORD RAILWAY STATION appended (148/2056)
# BEDFORD ST JOHNS RAILWAY STATION appended (149/2056)
# BEDHAMPTON RAILWAY STATION appended (150/2056)
# BEDMINSTER RAILWAY STATION appended (151/2056)
# BEDWORTH RAILWAY STATION appended (152/2056)
# BEESTON RAILWAY STATION appended (153/2056)
# BEKESBOURNE RAILWAY STATION appended (154/2056)
# BELLE BUE RAILWAY STATION appended (155/2056)
# BELLGROVE RAILWAY STATION appended (156/2056)
# BELLINGHAM RAILWAY STATION appended (157/2056)
# BELLSHILL RAILWAY STATION appended (158/2056)
# BELMONT RAILWAY STATION appended (159/2056)
# BELPER RAILWAY STATION appended (160/2056)
# BELTRING RAILWAY STATION appended (161/2056)
# BELVEDERE RAILWAY STATION appended (162/2056)
# BEN RHYDDING RAILWAY STATION appended (163/2056)
# BENFLEET RAILWAY STATION appended (164/2056)
# BENTHAM RAILWAY STATION appended (165/2056)
# BENTLEY RAILWAY STATION appended (166/2056)
# BERE FERRERS RAILWAY STATION appended (167/2056)
# BERKHAMSTED RAILWAY STATION appended (168/2056)
# BERKSWELL RAILWAY STATION appended (169/2056)
# BERRY BROW RAILWAY STATION appended (170/2056)
# BERRYLANDS RAILWAY STATION appended (171/2056)
# BERWICK RAILWAY STATION appended (172/2056)
# BERWICK UPON TWEED RAILWAY STATION appended (173/2056)
# BESCOT STADIUM RAILWAY STATION appended (174/2056)
# BETHNAL GREEN RAILWAY STATION appended (175/2056)
# BEVERLEY RAILWAY STATION appended (176/2056)
# BEXHILL RAILWAY STATION appended (177/2056)
# BEXLEY RAILWAY STATION appended (178/2056)
# BEXLEYHEATH RAILWAY STATION appended (179/2056)
# BICESTER NORTH RAILWAY STATION appended (180/2056)
# BICESTER VILLAGE RAILWAY STATION appended (181/2056)
# BICKLEY RAILWAY STATION appended (182/2056)
# BIDSTON RAILWAY STATION appended (183/2056)
# BIGGLESWADE RAILWAY STATION appended (184/2056)
# BILBROOK RAILWAY STATION appended (185/2056)
# BILLERICAY RAILWAY STATION appended (186/2056)
# BILLINGHAM RAILWAY STATION appended (187/2056)
# BILLINGSHURST RAILWAY STATION appended (188/2056)
# BINGHAM RAILWAY STATION appended (189/2056)
# BINGLEY RAILWAY STATION appended (190/2056)
# BIRCHGROVE RAILWAY STATION appended (191/2056)
# BIRCHINGTON ON SEA RAILWAY STATION appended (192/2056)
# BIRCHWOOD RAILWAY STATION appended (193/2056)
# BIRKBECK RAILWAY STATION appended (194/2056)
# BIRKDALE RAILWAY STATION appended (195/2056)
# BIRKENHEAD CENTRAL RAILWAY STATION appended (196/2056)
# BIRKENHEAD NORTH RAILWAY STATION appended (197/2056)
# BIRKENHEAD PARK RAILWAY STATION appended (198/2056)
# BIRMINGHAM INTERNATIONAL RAILWAY STATION appended (199/2056)
# BIRMINGHAM MOOR STREET RAILWAY STATION appended (200/2056)
# BIRMINGHAM NEW STREET RAILWAY STATION appended (201/2056)
# BIRMINGHAM SNOW HILL RAILWAY STATION appended (202/2056)
# BISHOP AUCKLAND RAILWAY STATION appended (203/2056)
# BISHOPBRIGGS RAILWAY STATION appended (204/2056)
# BISHOPS STORTFORD RAILWAY STATION appended (205/2056)
# BISHOPSTONE RAILWAY STATION appended (206/2056)
# BISHOPTON RAILWAY STATION appended (207/2056)
# BITTERNE RAILWAY STATION appended (208/2056)
# BLACKBURN RAILWAY STATION appended (209/2056)
# BLACKFRIARS RAILWAY STATION appended (210/2056)
# BLACKHEATH RAILWAY STATION appended (211/2056)
# BLACKPOOL PLEASURE BEACH RAILWAY STATION appended (212/2056)
# BLACKPOOL SOUTH RAILWAY STATION appended (213/2056)
# BLACKRIDGE RAILWAY STATION appended (214/2056)
# BLACKROD RAILWAY STATION appended (215/2056)
# BLACKWATER RAILWAY STATION appended (216/2056)
# BLAIR ATHOLL RAILWAY STATION appended (217/2056)
# BLAKE STREET RAILWAY STATION appended (218/2056)
# BLANTYRE RAILWAY STATION appended (219/2056)
# BLETCHLEY RAILWAY STATION appended (220/2056)
# BLOXWICH RAILWAY STATION appended (221/2056)
# BLUNDELLSANDS AND CROSBY RAILWAY STATION appended (222/2056)
# BOARD GREEN RAILWAY STATION appended (223/2056)
# BOGNOR REGIS RAILWAY STATION appended (224/2056)
# BOGSTON RAILWAY STATION appended (225/2056)
# BOLTON UPON DEARNE RAILWAY STATION appended (226/2056)
# BOOKHAM RAILWAY STATION appended (227/2056)
# BOOKING HALL KIOSK BASINGSTOKE RAILWAY STATION appended (228/2056)
# BOOTLE NEW STRAND RAILWAY STATION appended (229/2056)
# BOOTLE ORIEL ROAD RAILWAY STATION appended (230/2056)
# BOOTLE RAILWAY STATION appended (231/2056)
# BORDESLEY RAILWAY STATION appended (232/2056)
# BOROUGH GREEN AND WROTHAM RAILWAY STATION appended (233/2056)
# BORTH RAILWAY STATION appended (234/2056)
# BOSHAM RAILWAY STATION appended (235/2056)
# BOTLEY RAILWAY STATION appended (236/2056)
# BOTTESFORD RAILWAY STATION appended (237/2056)
# BOURNE END RAILWAY STATION appended (238/2056)
# BOURNEMOUTH RAILWAY STATION appended (239/2056)
# BOURNVILLE RAILWAY STATION appended (240/2056)
# BOWES PARK RAILWAY STATION appended (241/2056)
# BOWLING RAILWAY STATION appended (242/2056)
# BOXHILL AND WESTHUMBLE RAILWAY STATION appended (243/2056)
# BRACKNELL RAILWAY STATION appended (244/2056)
# BRADFORD FORSTER SQUARE RAILWAY STATION appended (245/2056)
# BRADFORD ON AVON RAILWAY STATION appended (246/2056)
# BRAINTREE FREEPORT RAILWAY STATION appended (247/2056)
# BRAINTREE RAILWAY STATION appended (248/2056)
# BRAMHALL RAILWAY STATION appended (249/2056)
# BRAMLEY RAILWAY STATION appended (250/2056)
# BRAMPTON RAILWAY STATION appended (251/2056)
# BRANCHTON RAILWAY STATION appended (252/2056)
# BRANDON RAILWAY STATION appended (253/2056)
# BRANKSOME RAILWAY STATION appended (254/2056)
# BREDBURY RAILWAY STATION appended (255/2056)
# BRENTFORD RAILWAY STATION appended (256/2056)
# BRENTWOOD RAILWAY STATION appended (257/2056)
# BRICKET WOOD RAILWAY STATION appended (258/2056)
# BRIDGE OF ALLAN RAILWAY STATION appended (259/2056)
# BRIDGE OF ORCHY RAILWAY STATION appended (260/2056)
# BRIDGEND RAILWAY STATION appended (261/2056)
# BRIDGETON RAILWAY STATION appended (262/2056)
# BRIDGWATER RAILWAY STATION appended (263/2056)
# BRIDLINGTON RAILWAY STATION appended (264/2056)
# BRIERFIELD RAILWAY STATION appended (265/2056)
# BRIGHOUSE RAILWAY STATION appended (266/2056)
# BRIGHTON RAILWAY STATION appended (267/2056)
# BRIMSDOWN RAILWAY STATION appended (268/2056)
# BRINNINGTON RAILWAY STATION appended (269/2056)
# BRISTOL PARKWAY RAILWAY STATION appended (270/2056)
# BRISTOL TEMPLE MEADS RAILWAY STATION appended (271/2056)
# BRITHDIR RAILWAY STATION appended (272/2056)
# BRITON FERRY RAILWAY STATION appended (273/2056)
# BRIXTON RAILWAY STATION appended (274/2056)
# BROADBOTTOM RAILWAY STATION appended (275/2056)
# BROADSTAIRS RAILWAY STATION appended (276/2056)
# BROCKENHURST RAILWAY STATION appended (277/2056)
# BROCKHOLES RAILWAY STATION appended (278/2056)
# BROCKLEY RAILWAY STATION appended (279/2056)
# BROMBOROUGH RAILWAY STATION appended (280/2056)
# BROMBOROUGH RAKE RAILWAY STATION appended (281/2056)
# BROMLEY CROSS RAILWAY STATION appended (282/2056)
# BROMLEY NORTH RAILWAY STATION appended (283/2056)
# BROMLEY SOUTH RAILWAY STATION appended (284/2056)
# BROMSGROVE RAILWAY STATION appended (285/2056)
# BROOKMANS PARK RAILWAY STATION appended (286/2056)
# BROOKWOOD RAILWAY STATION appended (287/2056)
# BROUGH RAILWAY STATION appended (288/2056)
# BROUGHTY FERRY RAILWAY STATION appended (289/2056)
# BROXBOURNE RAILWAY STATION appended (290/2056)
# BRUCE GROVE RAILWAY STATION appended (291/2056)
# BRUNSTANE RAILWAY STATION appended (292/2056)
# BRUNSWICK RAILWAY STATION appended (293/2056)
# BRYN RAILWAY STATION appended (294/2056)
# BUCKLEY RAILWAY STATION appended (295/2056)
# BUCKSHAW PARKWAY RAILWAY STATION appended (296/2056)
# BUILTH ROAD RAILWAY STATION appended (297/2056)
# BULWELL RAILWAY STATION appended (298/2056)
# BURES RAILWAY STATION appended (299/2056)
# BURGESS HILL RAILWAY STATION appended (300/2056)
# BURLEY PARK RAILWAY STATION appended (301/2056)
# BURLEY-IN-WHARFEDALE RAILWAY STATION appended (302/2056)
# BURNAGE RAILWAY STATION appended (303/2056)
# BURNHAM ON CROUCH RAILWAY STATION appended (304/2056)
# BURNHAM RAILWAY STATION appended (305/2056)
# BURNLEY BARRACKS RAILWAY STATION appended (306/2056)
# BURNLEY CENTRAL RAILWAY STATION appended (307/2056)
# BURNLEY RAILWAY STATION appended (308/2056)
# BURNSIDE RAILWAY STATION appended (309/2056)
# BURNTISLAND RAILWAY STATION appended (310/2056)
# BURSCOUGH BRIDGE RAILWAY STATION appended (311/2056)
# BURSCOUGH JUNCTION RAILWAY STATION appended (312/2056)
# BURSLEDON RAILWAY STATION appended (313/2056)
# BURTON-ON-TRENT RAILWAY STATION appended (314/2056)
# BURY ST EDMUNDS RAILWAY STATION appended (315/2056)
# BUS SHELTER GBC 53 GUILDFORD RAILWAY STATION appended (316/2056)
# BUSBY RAILWAY STATION appended (317/2056)
# BUSH HILL PARK RAILWAY STATION appended (318/2056)
# BUTLERS LANE RAILWAY STATION appended (319/2056)
# BUXTED RAILWAY STATION appended (320/2056)
# BUXTON RAILWAY STATION appended (321/2056)
# BYFLEET AND NEW HAW RAILWAY STATION appended (322/2056)
# CADOXTON RAILWAY STATION appended (323/2056)
# CAERGWRLE RAILWAY STATION appended (324/2056)
# CAERPHILLY RAILWAY STATION appended (325/2056)
# CAERSWS RAILWAY STATION appended (326/2056)
# CALDERCRUIX RAILWAY STATION appended (327/2056)
# CALDICOT RAILWAY STATION appended (328/2056)
# CALSTOCK RAILWAY STATION appended (329/2056)
# CAM AND DURSLEY RAILWAY STATION appended (330/2056)
# CAMBERLEY RAILWAY STATION appended (331/2056)
# CAMBORNE RAILWAY STATION appended (332/2056)
# CAMBRIDGE HEATH RAILWAY STATION appended (333/2056)
# CAMBRIDGE NORTH RAILWAY STATION appended (334/2056)
# CAMBRIDGE RAILWAY STATION appended (335/2056)
# CAMBUSLANG RAILWAY STATION appended (336/2056)
# CAMDEN ROAD RAILWAY STATION appended (337/2056)
# CANLEY RAILWAY STATION appended (338/2056)
# CANNING TOWN RAILWAY STATION appended (339/2056)
# CANNOCK RAILWAY STATION appended (340/2056)
# CANNON STREET RAILWAY STATION appended (341/2056)
# CANTERBURY EAST RAILWAY STATION appended (342/2056)
# CANTERBURY WEST RAILWAY STATION appended (343/2056)
# CAPENHURST RAILWAY STATION appended (344/2056)
# CARDENDEN RAILWAY STATION appended (345/2056)
# CARDIFF BAY RAILWAY STATION appended (346/2056)
# CARDIFF CENTRAL RAILWAY STATION appended (347/2056)
# CARDIFF QUEEN STREET RAILWAY STATION appended (348/2056)
# CARDONALD RAILWAY STATION appended (349/2056)
# CARDROSS RAILWAY STATION appended (350/2056)
# CARFIN RAILWAY STATION appended (351/2056)
# CARK AND CARTMEL RAILWAY STATION appended (352/2056)
# CARLISLE RAILWAY STATION appended (353/2056)
# CARLTON RAILWAY STATION appended (354/2056)
# CARLUKE RAILWAY STATION appended (355/2056)
# CARMARTHEN RAILWAY STATION appended (356/2056)
# CARMYLE RAILWAY STATION appended (357/2056)
# CARNFORTH RAILWAY STATION appended (358/2056)
# CARNOUSTIE RAILWAY STATION appended (359/2056)
# CARNTYNE RAILWAY STATION appended (360/2056)
# CARRBRIDGE RAILWAY STATION appended (361/2056)
# CARSHALTON BEECHES RAILWAY STATION appended (362/2056)
# CARSHALTON RAILWAY STATION appended (363/2056)
# CARTSDYKE RAILWAY STATION appended (364/2056)
# CASTLE CARY RAILWAY STATION appended (365/2056)
# CASTLE RAILWAY STATION appended (366/2056)
# CASTLEBAR PARK RAILWAY STATION appended (367/2056)
# CASTLEFORD RAILWAY STATION appended (368/2056)
# CASTLETON RAILWAY STATION appended (369/2056)
# CATERHAM RAILWAY STATION appended (370/2056)
# CATFORD BRIDGE RAILWAY STATION appended (371/2056)
# CATFORD RAILWAY STATION appended (372/2056)
# CATHAYS RAILWAY STATION appended (373/2056)
# CATHCART RAILWAY STATION appended (374/2056)
# CATTAL RAILWAY STATION appended (375/2056)
# CAUSELAND RAILWAY STATION appended (376/2056)
# CENTRAL RAILWAY STATION appended (377/2056)
# CHADWELL HEATH RAILWAY STATION appended (378/2056)
# CHAFFORD HUNDRED RAILWAY STATION appended (379/2056)
# CHALFONT AND LATIMER RAILWAY STATION appended (380/2056)
# CHALKWELL RAILWAY STATION appended (381/2056)
# CHANDLER'S FORD RAILWAY STATION appended (382/2056)
# CHAPELTOWN RAILWAY STATION appended (383/2056)
# CHAPLE EN LE FRITH RAILWAY STATION appended (384/2056)
# CHAPPEL AND WAKES COLNE RAILWAY STATION appended (385/2056)
# CHARING CROSS RAILWAY STATION appended (386/2056)
# CHARING RAILWAY STATION appended (387/2056)
# CHARLBURY RAILWAY STATION appended (388/2056)
# CHARLTON RAILWAY STATION appended (389/2056)
# CHARTHAM RAILWAY STATION appended (390/2056)
# CHASSEN ROAD RAILWAY STATION appended (391/2056)
# CHATELHERAULT RAILWAY STATION appended (392/2056)
# CHATHAM RAILWAY STATION appended (393/2056)
# CHEADLE HULME RAILWAY STATION appended (394/2056)
# CHEAM RAILWAY STATION appended (395/2056)
# CHEDDINGTON RAILWAY STATION appended (396/2056)
# CHELFORD RAILWAY STATION appended (397/2056)
# CHELMSFORD RAILWAY STATION appended (398/2056)
# CHELSFIELD RAILWAY STATION appended (399/2056)
# CHELTENHAM SPA RAILWAY STATION appended (400/2056)
# CHEPSTOW RAILWAY STATION appended (401/2056)
# CHERRY TREE RAILWAY STATION appended (402/2056)
# CHERTSEY RAILWAY STATION appended (403/2056)
# CHESHUNT RAILWAY STATION appended (404/2056)
# CHESSINGTON NORTH RAILWAY STATION appended (405/2056)
# CHESSINGTON SOUTH RAILWAY STATION appended (406/2056)
# CHESTER LE STREET RAILWAY STATION appended (407/2056)
# CHESTER RAILWAY STATION appended (408/2056)
# CHESTER ROAD RAILWAY STATION appended (409/2056)
# CHESTERFIELD RAILWAY STATION appended (410/2056)
# CHESTFIELD AND SWALECLIFFE RAILWAY STATION appended (411/2056)
# CHICHESTER RAILWAY STATION appended (412/2056)
# CHILHAM RAILWAY STATION appended (413/2056)
# CHINGFORD RAILWAY STATION appended (414/2056)
# CHINLEY RAILWAY STATION appended (415/2056)
# CHIPPENHAM RAILWAY STATION appended (416/2056)
# CHIPSTEAD RAILWAY STATION appended (417/2056)
# CHISLEHURST RAILWAY STATION appended (418/2056)
# CHISWICK RAILWAY STATION appended (419/2056)
# CHOLSEY RAILWAY STATION appended (420/2056)
# CHORLEY RAILWAY STATION appended (421/2056)
# CHRISTCHURCH RAILWAY STATION appended (422/2056)
# CHURCH AND OSWALDTWISTLE RAILWAY STATION appended (423/2056)
# CHURCH FENTON RAILWAY STATION appended (424/2056)
# CHURCH STRETTON RAILWAY STATION appended (425/2056)
# CHURCHILL AND BLAKEDOWN RAILWAY STATION appended (426/2056)
# CITY THAMESLINK RAILWAY STATION appended (427/2056)
# CLACTON ON SEA RAILWAY STATION appended (428/2056)
# CLANDON RAILWAY STATION appended (429/2056)
# CLAPHAM HIGH STREET RAILWAY STATION appended (430/2056)
# CLAPHAM JUNCTION RAILWAY STATION appended (431/2056)
# CLAPHAM RAILWAY STATION appended (432/2056)
# CLAPTON RAILWAY STATION appended (433/2056)
# CLARKSTON RAILWAY STATION appended (434/2056)
# CLAYGATE RAILWAY STATION appended (435/2056)
# CLEETHORPES RAILWAY STATION appended (436/2056)
# CLELAND RAILWAY STATION appended (437/2056)
# CLIFTON DOWN RAILWAY STATION appended (438/2056)
# CLIFTON RAILWAY STATION appended (439/2056)
# CLITHEROE RAILWAY STATION appended (440/2056)
# CLOCK HOUSE RAILWAY STATION appended (441/2056)
# CLYDEBANK RAILWAY STATION appended (442/2056)
# COATBRIDGE CENTRAL RAILWAY STATION appended (443/2056)
# COATDYKE RAILWAY STATION appended (444/2056)
# COBHAM AND STOKE D'ABERNON RAILWAY STATION appended (445/2056)
# CODSALL RAILWAY STATION appended (446/2056)
# COGAN RAILWAY STATION appended (447/2056)
# COLCHESTER RAILWAY STATION appended (448/2056)
# COLCHESTER TOWN RAILWAY STATION appended (449/2056)
# COLESHILL PARKWAY RAILWAY STATION appended (450/2056)
# COLLINGHAM RAILWAY STATION appended (451/2056)
# COLLINGTON RAILWAY STATION appended (452/2056)
# COLNE RAILWAY STATION appended (453/2056)
# COLWALL RAILWAY STATION appended (454/2056)
# CONGLETON RAILWAY STATION appended (455/2056)
# CONISBROUGH RAILWAY STATION appended (456/2056)
# CONON BRIDGE RAILWAY STATION appended (457/2056)
# CONONLEY RAILWAY STATION appended (458/2056)
# CONWAY PARK RAILWAY STATION appended (459/2056)
# CONWY RAILWAY STATION appended (460/2056)
# COODEN BEACH RAILWAY STATION appended (461/2056)
# COOKHAM RAILWAY STATION appended (462/2056)
# COOKSBRIDGE RAILWAY STATION appended (463/2056)
# COOMBE JUNCTION RAILWAY STATION appended (464/2056)
# CORBRIDGE RAILWAY STATION appended (465/2056)
# CORBY RAILWAY STATION appended (466/2056)
# CORKERHILL RAILWAY STATION appended (467/2056)
# CORKICKLE RAILWAY STATION appended (468/2056)
# CORYTON RAILWAY STATION appended (469/2056)
# COSELEY RAILWAY STATION appended (470/2056)
# COSFORD RAILWAY STATION appended (471/2056)
# COTTINGHAM RAILWAY STATION appended (472/2056)
# COTTINGLEY RAILWAY STATION appended (473/2056)
# COULSDON SOUTH RAILWAY STATION appended (474/2056)
# COULSDON TOWN RAILWAY STATION appended (475/2056)
# COVENTRY ARENA RAILWAY STATION appended (476/2056)
# COVENTRY RAILWAY STATION appended (477/2056)
# COWDENBEATH RAILWAY STATION appended (478/2056)
# CRADLEY HEATH RAILWAY STATION appended (479/2056)
# CRAIGENDORAN RAILWAY STATION appended (480/2056)
# CRAMLINGTON RAILWAY STATION appended (481/2056)
# CRANBROOK RAILWAY STATION appended (482/2056)
# CRAVEN ARMS RAILWAY STATION appended (483/2056)
# CRAWLEY RAILWAY STATION appended (484/2056)
# CRAYFORD RAILWAY STATION appended (485/2056)
# CREDITON RAILWAY STATION appended (486/2056)
# CRESSING RAILWAY STATION appended (487/2056)
# CRESSINGTON RAILWAY STATION appended (488/2056)
# CRESWELL RAILWAY STATION appended (489/2056)
# CREWE RAILWAY STATION appended (490/2056)
# CREWKERNE RAILWAY STATION appended (491/2056)
# CREWS HILL RAILWAY STATION appended (492/2056)
# CRICKLEWOOD RAILWAY STATION appended (493/2056)
# CROFTFOOT RAILWAY STATION appended (494/2056)
# CROFTON PARK RAILWAY STATION appended (495/2056)
# CROMER RAILWAY STATION appended (496/2056)
# CROOKSTON RAILWAY STATION appended (497/2056)
# CROSS GATES RAILWAY STATION appended (498/2056)
# CROSSFLATTS RAILWAY STATION appended (499/2056)
# CROSSHILL RAILWAY STATION appended (500/2056)
# CROSSKEYS RAILWAY STATION appended (501/2056)
# CROSSMYLOOF RAILWAY STATION appended (502/2056)
# CROSTON RAILWAY STATION appended (503/2056)
# CROWBOROUGH RAILWAY STATION appended (504/2056)
# CROWHURST RAILWAY STATION appended (505/2056)
# CROWTHORNE RAILWAY STATION appended (506/2056)
# CRYSTAL PALACE RAILWAY STATION appended (507/2056)
# CUDDINGTON RAILWAY STATION appended (508/2056)
# CUFFLEY RAILWAY STATION appended (509/2056)
# CULHAM RAILWAY STATION appended (510/2056)
# CUPAR RAILWAY STATION appended (511/2056)
# CUXTON RAILWAY STATION appended (512/2056)
# CWMBACH VALLEYS RAILWAY STATION appended (513/2056)
# DAGENHAM DOCK RAILWAY STATION appended (514/2056)
# DAISY HILL RAILWAY STATION appended (515/2056)
# DALMARNOCK RAILWAY STATION appended (516/2056)
# DALMUIR RAILWAY STATION appended (517/2056)
# DALREOCH RAILWAY STATION appended (518/2056)
# DALRY RAILWAY STATION appended (519/2056)
# DALSTON RAILWAY STATION appended (520/2056)
# DALTON-IN-FURNESS RAILWAY STATION appended (521/2056)
# DANESCOURT RAILWAY STATION appended (522/2056)
# DANZEY RAILWAY STATION appended (523/2056)
# DARNALL RAILWAY STATION appended (524/2056)
# DARSHAM RAILWAY STATION appended (525/2056)
# DARTFORD RAILWAY STATION appended (526/2056)
# DARTON RAILWAY STATION appended (527/2056)
# DARWEN RAILWAY STATION appended (528/2056)
# DATCHET RAILWAY STATION appended (529/2056)
# DAVENPORT RAILWAY STATION appended (530/2056)
# DAWLISH RAILWAY STATION appended (531/2056)
# DAWLISH WARREN RAILWAY STATION appended (532/2056)
# DEAL RAILWAY STATION appended (533/2056)
# DEAN RAILWAY STATION appended (534/2056)
# DEANSGATE RAILWAY STATION appended (535/2056)
# DEIGHTON RAILWAY STATION appended (536/2056)
# DELAMERE RAILWAY STATION appended (537/2056)
# DENBY DALE RAILWAY STATION appended (538/2056)
# DENHAM GOLF CLUB RAILWAY STATION appended (539/2056)
# DENHAM RAILWAY STATION appended (540/2056)
# DENMARK HILL RAILWAY STATION appended (541/2056)
# DENTON RAILWAY STATION appended (542/2056)
# DEPTFORD RAILWAY STATION appended (543/2056)
# DERBYRAILWAY STATION appended (544/2056)
# DEWSBURY RAILWAY STATION appended (545/2056)
# DIDCOT PARKWAY RAILWAY STATION appended (546/2056)
# DINAS POWYS RAILWAY STATION appended (547/2056)
# DINAS RHONDDA RAILWAY STATION appended (548/2056)
# DINGLE ROAD RAILWAY STATION appended (549/2056)
# DINGWALL RAILWAY STATION appended (550/2056)
# DINSDALE RAILWAY STATION appended (551/2056)
# DINTING RAILWAY STATION appended (552/2056)
# DISLEY RAILWAY STATION appended (553/2056)
# DISS RAILWAY STATION appended (554/2056)
# DODWORTH RAILWAY STATION appended (555/2056)
# DONCASTER RAILWAY STATION appended (556/2056)
# DORCHESTER SOUTH RAILWAY STATION appended (557/2056)
# DORCHESTER WEST RAILWAY STATION appended (558/2056)
# DORE AND TOTLEY RAILWAY STATION appended (559/2056)
# DORKING DEEPDENE RAILWAY STATION appended (560/2056)
# DORKING RAILWAY STATION appended (561/2056)
# DORKING WEST RAILWAY STATION appended (562/2056)
# DORMANS RAILWAY STATION appended (563/2056)
# DORRIDGE RAILWAY STATION appended (564/2056)
# DOVE HOLES RAILWAY STATION appended (565/2056)
# DOVER PRIORY RAILWAY STATION appended (566/2056)
# DOVERCOURT RAILWAY STATION appended (567/2056)
# DOWNHAM MARKET RAILWAY STATION appended (568/2056)
# DRAYTON PARK RAILWAY STATION appended (569/2056)
# DREM RAILWAY STATION appended (570/2056)
# DRIFFIELD RAILWAY STATION appended (571/2056)
# DROITWICH SPA RAILWAY STATION appended (572/2056)
# DRONFIELD RAILWAY STATION appended (573/2056)
# DRUMCHAPEL RAILWAY STATION appended (574/2056)
# DRUMFROCHAR RAILWAY STATION appended (575/2056)
# DRUMGELLOCH RAILWAY STATION appended (576/2056)
# DRUMRY RAILWAY STATION appended (577/2056)
# DUDDESTON RAILWAY STATION appended (578/2056)
# DUDLEY PORT RAILWAY STATION appended (579/2056)
# DUKE STREET RAILWAY STATION appended (580/2056)
# DULLINGHAM RAILWAY STATION appended (581/2056)
# DUMBARTON CENTRAL RAILWAY STATION appended (582/2056)
# DUMBARTON EAST RAILWAY STATION appended (583/2056)
# DUMBRECK RAILWAY STATION appended (584/2056)
# DUMFRIES RAILWAY STATION appended (585/2056)
# DUMPTON PARK RAILWAY STATION appended (586/2056)
# DUNBAR RAILWAY STATION appended (587/2056)
# DUNBLANE RAILWAY STATION appended (588/2056)
# DUNDEE RAILWAY STATION appended (589/2056)
# DUNFERMLINE QUEEN MARGARET RAILWAY STATION appended (590/2056)
# DUNFERMLINE TOWN RAILWAY STATION appended (591/2056)
# DUNLOP RAILWAY STATION appended (592/2056)
# DUNTON GREEN RAILWAY STATION appended (593/2056)
# DURHAM RAILWAY STATION appended (594/2056)
# DURRINGTON ON SEA RAILWAY STATION appended (595/2056)
# DYCE RAILWAY STATION appended (596/2056)
# EAGLESCLIFFE RAILWAY STATION appended (597/2056)
# EALING BROADWAY RAILWAY STATION appended (598/2056)
# EARLESTOWN RAILWAY STATION appended (599/2056)
# EARLEY RAILWAY STATION appended (600/2056)
# EARLSWOOD RAILWAY STATION appended (601/2056)
# EAST CROYDON RAILWAY STATION appended (602/2056)
# EAST DIDSBURY RAILWAY STATION appended (603/2056)
# EAST DULWICH RAILWAY STATION appended (604/2056)
# EAST FARLEIGH RAILWAY STATION appended (605/2056)
# EAST GARFORTH RAILWAY STATION appended (606/2056)
# EAST GRINSTEAD RAILWAY STATION appended (607/2056)
# EAST KILBRIDE RAILWAY STATION appended (608/2056)
# EAST MALLING RAILWAY STATION appended (609/2056)
# EAST MIDLANDS PARKWAY RAILWAY STATION appended (610/2056)
# EAST TILBURY RAILWAY STATION appended (611/2056)
# EAST WORTHING RAILWAY STATION appended (612/2056)
# EASTBOURNE RAILWAY STATION appended (613/2056)
# EASTBROOK RAILWAY STATION appended (614/2056)
# EASTERHOUSE RAILWAY STATION appended (615/2056)
# EASTHAM RAKE RAILWAY STATION appended (616/2056)
# EASTLEIGH RAILWAY STATION appended (617/2056)
# EBBSFLEET INTERNATIONAL RAILWAY STATION appended (618/2056)
# EBBW VALE PARKWAY RAILWAY STATION appended (619/2056)
# EBBW VALE TOWN RAILWAY STATION appended (620/2056)
# ECCLES (MANCHESTER) RAILWAY STATION appended (621/2056)
# ECCLESTON PARK RAILWAY STATION appended (622/2056)
# EDEN PARK RAILWAY STATION appended (623/2056)
# EDENBRIDGE RAILWAY STATION appended (624/2056)
# EDENBRIDGE TOWN RAILWAY STATION appended (625/2056)
# EDINBURGH GATEWAY RAILWAY STATION appended (626/2056)
# EDINBURGH PARK RAILWAY STATION appended (627/2056)
# EDINBURGH WAVERLEY RAILWAY STATION appended (628/2056)
# EDMONTON GREEN RAILWAY STATION appended (629/2056)
# EFFINGHAM JUNCTION RAILWAY STATION appended (630/2056)
# EGGESFORD RAILWAY STATION appended (631/2056)
# EGHAM RAILWAY STATION appended (632/2056)
# ELEPHANT AND CASTLE RAILWAY STATION appended (633/2056)
# ELGIN RAILWAY STATION appended (634/2056)
# ELLESMERE PORT RAILWAY STATION appended (635/2056)
# ELMERS END RAILWAY STATION appended (636/2056)
# ELMSTEAD WOODS RAILWAY STATION appended (637/2056)
# ELMSWELL RAILWAY STATION appended (638/2056)
# ELSECAR RAILWAY STATION appended (639/2056)
# ELSENHAM RAILWAY STATION appended (640/2056)
# ELSTREE AND BOREHAMWOOD RAILWAY STATION appended (641/2056)
# ELTHAM RAILWAY STATION appended (642/2056)
# ELTON AND ORSTON RAILWAY STATION appended (643/2056)
# ELY RAILWAY STATION appended (644/2056)
# EMERSON PARK RAILWAY STATION appended (645/2056)
# EMSWORTH RAILWAY STATION appended (646/2056)
# ENERGLYN AND CHURCHILL PARK RAILWAY STATION appended (647/2056)
# ENFIELD CHASE RAILWAY STATION appended (648/2056)
# ENFIELD LOCK RAILWAY STATION appended (649/2056)
# ENFIELD TOWN RAILWAY STATION appended (650/2056)
# EPSOM DOWNS RAILWAY STATION appended (651/2056)
# EPSOM RAILWAY STATION appended (652/2056)
# ERDINGTON RAILWAY STATION appended (653/2056)
# ERITH RAILWAY STATION appended (654/2056)
# ESHER RAILWAY STATION appended (655/2056)
# ESKBANK RAILWAY STATION appended (656/2056)
# ESSEX ROAD RAILWAY STATION appended (657/2056)
# ETCHINGHAM RAILWAY STATION appended (658/2056)
# EUSTON RAILWAY STATION appended (659/2056)
# EUXTON RAILWAY STATION appended (660/2056)
# EVESHAM RAILWAY STATION appended (661/2056)
# EWELL EAST RAILWAY STATION appended (662/2056)
# EWELL WEST RAILWAY STATION appended (663/2056)
# EXETER ST DAVIDS RAILWAY STATION appended (664/2056)
# EXETER ST JAMES PARK RAILWAY STATION appended (665/2056)
# EXETER ST THOMAS RAILWAY STATION appended (666/2056)
# EXHIBITION CENTRE RAILWAY STATION appended (667/2056)
# EXMOUTH RAILWAY STATION appended (668/2056)
# EYNSFORD RAILWAY STATION appended (669/2056)
# FAIRFIELD RAILWAY STATION appended (670/2056)
# FAIRWATER RAILWAY STATION appended (671/2056)
# FALCONWOOD RAILWAY STATION appended (672/2056)
# FALKIRK GRAHAMSTON RAILWAY STATION appended (673/2056)
# FALMER RAILWAY STATION appended (674/2056)
# FALMOUTH TOWN RAILWAY STATION appended (675/2056)
# FAREHAM RAILWAY STATION appended (676/2056)
# FARNBOROUGH NORTH RAILWAY STATION appended (677/2056)
# FARNBOROUGH RAILWAY STATION appended (678/2056)
# FARNCOMBE RAILWAY STATION appended (679/2056)
# FARNHAM RAILWAY STATION appended (680/2056)
# FARNINGHAM ROAD RAILWAY STATION appended (681/2056)
# FARRINGDON RAILWAY STATION appended (682/2056)
# FAULDHOUSE RAILWAY STATION appended (683/2056)
# FAVERSHAM RAILWAY STATION appended (684/2056)
# FAZAKERLEY RAILWAY STATION appended (685/2056)
# FEATHERSTONE RAILWAY STATION appended (686/2056)
# FELIXSTOWE TOWN RAILWAY STATION appended (687/2056)
# FELTHAM RAILWAY STATION appended (688/2056)
# FENCHURCH STREET RAILWAY STATION appended (689/2056)
# FENITON RAILWAY STATION appended (690/2056)
# FERNHILL RAILWAY STATION appended (691/2056)
# FERRYSIDE RAILWAY STATION appended (692/2056)
# FILEY RAILWAY STATION appended (693/2056)
# FINCHLEY ROAD AND FROGNAL RAILWAY STATION appended (694/2056)
# FINSBURY PARK RAILWAY STATION appended (695/2056)
# FISHBOURNE RAILWAY STATION appended (696/2056)
# FISHERSGATE RAILWAY STATION appended (697/2056)
# FITZWILLIAM RAILWAY STATION appended (698/2056)
# FIVE WAYS RAILWAY STATION appended (699/2056)
# FLEET RAILWAY STATION appended (700/2056)
# FLIMBY RAILWAY STATION appended (701/2056)
# FLINT RAILWAY STATION appended (702/2056)
# FLITWICK RAILWAY STATION appended (703/2056)
# FLIXTON RAILWAY STATION appended (704/2056)
# FLOWERY FIELD RAILWAY STATION appended (705/2056)
# FOLKESTONE CENTRAL RAILWAY STATION appended (706/2056)
# FOLKESTONE WEST RAILWAY STATION appended (707/2056)
# FORD RAILWAY STATION appended (708/2056)
# FOREST GATE RAILWAY STATION appended (709/2056)
# FOREST HILL RAILWAY STATION appended (710/2056)
# FORMBY RAILWAY STATION appended (711/2056)
# FORMER CHAPEL EN LE FRITH RAILWAY STATION appended (712/2056)
# FORMER UNIT 5 CHELMSFORD RAILWAY STATION appended (713/2056)
# FORRES RAILWAY STATION appended (714/2056)
# FORT MATILDA RAILWAY STATION appended (715/2056)
# FORT WILLIAM RAILWAY STATION appended (716/2056)
# FOUR OAKS RAILWAY STATION appended (717/2056)
# FOXFIELD RAILWAY STATION appended (718/2056)
# FOXTON RAILWAY STATION appended (719/2056)
# FRANT RAILWAY STATION appended (720/2056)
# FRATTON RAILWAY STATION appended (721/2056)
# FRESHFIELD RAILWAY STATION appended (722/2056)
# FRESHFORD RAILWAY STATION appended (723/2056)
# FRIMLEY RAILWAY STATION appended (724/2056)
# FRINTON ON SEA RAILWAY STATION appended (725/2056)
# FRIZINGHALL RAILWAY STATION appended (726/2056)
# FRODSHAM RAILWAY STATION appended (727/2056)
# FROME RAILWAY STATION appended (728/2056)
# FULWELL RAILWAY STATION appended (729/2056)
# FURNESS VALE RAILWAY STATION appended (730/2056)
# GAINSBOROUGH CENTRAL RAILWAY STATION appended (731/2056)
# GAINSBOROUGH LEA ROAD RAILWAY STATION appended (732/2056)
# GALASHIELS RAILWAY STATION appended (733/2056)
# GARELOCHHEAD RAILWAY STATION appended (734/2056)
# GARFORTH RAILWAY STATION appended (735/2056)
# GARROWHILL RAILWAY STATION appended (736/2056)
# GARSCADDEN RAILWAY STATION appended (737/2056)
# GARSDALE RAILWAY STATION appended (738/2056)
# GARSTON RAILWAY STATION appended (739/2056)
# GARSWOOD RAILWAY STATION appended (740/2056)
# GARTCOSH RAILWAY STATION appended (741/2056)
# GARTH (POWYS) RAILWAY STATION appended (742/2056)
# GARTH RAILWAY STATION appended (743/2056)
# GATHURST RAILWAY STATION appended (744/2056)
# GATLEY RAILWAY STATION appended (745/2056)
# GATWICK AIRPORT RAILWAY STATION appended (746/2056)
# GATWICK RAILWAY STATION appended (747/2056)
# GERRARDS CROSS RAILWAY STATION appended (748/2056)
# GIDEA PARK RAILWAY STATION appended (749/2056)
# GIFFNOCK RAILWAY STATION appended (750/2056)
# GILBERDYKE RAILWAY STATION appended (751/2056)
# GILFACH FARGOED RAILWAY STATION appended (752/2056)
# GILSHOCHILL RAILWAY STATION appended (753/2056)
# GIPSY HILL RAILWAY STATION appended (754/2056)
# GIRVAN RAILWAY STATION appended (755/2056)
# GLAN CONWY RAILWAY STATION appended (756/2056)
# GLASGOW CENTRAL RAILWAY STATION appended (757/2056)
# GLASGOW PRESTWICK INTERNATIONAL AIRPORT RAILWAY STATION appended (758/2056)
# GLASGOW QUEEN STREET RAILWAY STATION appended (759/2056)
# GLASSHOUGHTON RAILWAY STATION appended (760/2056)
# GLAZEBROOK RAILWAY STATION appended (761/2056)
# GLOSSOP RAILWAY STATION appended (762/2056)
# GLOUCESTER RAILWAY STATION appended (763/2056)
# GLYNDE RAILWAY STATION appended (764/2056)
# GOBOWEN RAILWAY STATION appended (765/2056)
# GODALMING RAILWAY STATION appended (766/2056)
# GODLEY RAILWAY STATION appended (767/2056)
# GODSTONE RAILWAY STATION appended (768/2056)
# GOLDTHORPE RAILWAY STATION appended (769/2056)
# GOMSHALL RAILWAY STATION appended (770/2056)
# GOODMAYES RAILWAY STATION appended (771/2056)
# GOOLE RAILWAY STATION appended (772/2056)
# GOOSTREY RAILWAY STATION appended (773/2056)
# GORDON HILL RAILWAY STATION appended (774/2056)
# GORING AND STREATLEY RAILWAY STATION appended (775/2056)
# GORING BY SEA RAILWAY STATION appended (776/2056)
# GORTON RAILWAY STATION appended (777/2056)
# GOSPEL OAK RAILWAY STATION appended (778/2056)
# GOUROCK RAILWAY STATION appended (779/2056)
# GOWERTON RAILWAY STATION appended (780/2056)
# GRANGE OVER SANDS RAILWAY STATION appended (781/2056)
# GRANGE PARK RAILWAY STATION RAILWAY STATION appended (782/2056)
# GRANGETOWN RAILWAY STATION appended (783/2056)
# GRANTHAM RAILWAY STATION appended (784/2056)
# GRATELEY RAILWAY STATION appended (785/2056)
# GRAVESEND RAILWAY STATION appended (786/2056)
# GRAYS RAILWAY STATION appended (787/2056)
# GREAT AYTON RAILWAY STATION appended (788/2056)
# GREAT BENTLEY RAILWAY STATION appended (789/2056)
# GREAT CHESTERFORD RAILWAY STATION appended (790/2056)
# GREAT COATES RAILWAY STATION appended (791/2056)
# GREAT MISSENDEN RAILWAY STATION appended (792/2056)
# GREAT SHELFORD RAILWAY STATION appended (793/2056)
# GREEN LANE RAILWAY STATION appended (794/2056)
# GREENBANK RAILWAY STATION appended (795/2056)
# GREENFIELD RAILWAY STATION appended (796/2056)
# GREENFORD RAILWAY STATION appended (797/2056)
# GREENHITHE RAILWAY STATION appended (798/2056)
# GREENOCK CENTRAL RAILWAY STATION appended (799/2056)
# GRETNA GREEN RAILWAY STATION appended (800/2056)
# GRIMSBY DOCKS RAILWAY STATION appended (801/2056)
# GRIMSBY TOWN RAILWAY STATION appended (802/2056)
# GRINDLEFORD RAILWAY STATION appended (803/2056)
# GROVE PARK RAILWAY STATION appended (804/2056)
# GUIDE BRIDGE RAILWAY STATION appended (805/2056)
# GUILDFORD RAILWAY STATION appended (806/2056)
# GUISELEY RAILWAY STATION appended (807/2056)
# GUNNERSBURY RAILWAY STATION appended (808/2056)
# GUNNISLAKE RAILWAY STATION appended (809/2056)
# GWERSYLLT RAILWAY STATION appended (810/2056)
# HACKBRIDGE RAILWAY STATION appended (811/2056)
# HACKNEY DOWNS RAILWAY STATION appended (812/2056)
# HADDISCOE RAILWAY STATION appended (813/2056)
# HADFIELD RAILWAY STATION appended (814/2056)
# HADLEY WOOD RAILWAY STATION appended (815/2056)
# HAG FOLD RAILWAY STATION appended (816/2056)
# HAGLEY RAILWAY STATION appended (817/2056)
# HALE RAILWAY STATION appended (818/2056)
# HALESWORTH RAILWAY STATION appended (819/2056)
# HALIFAX RAILWAY STATION appended (820/2056)
# HALL GREEN RAILWAY STATION appended (821/2056)
# HALL ROAD RAILWAY STATION appended (822/2056)
# HALL-I'-TH'-WOOD RAILWAY STATION appended (823/2056)
# HALLING RAILWAY STATION appended (824/2056)
# HALTWHISTLE RAILWAY STATION appended (825/2056)
# HAM STREET RAILWAY STATION appended (826/2056)
# HAMBLE RAILWAY STATION appended (827/2056)
# HAMILTON SQUARE RAILWAY STATION appended (828/2056)
# HAMILTON WEST RAILWAY STATION appended (829/2056)
# HAMPDEN PARK RAILWAY STATION appended (830/2056)
# HAMPSTEAD HEATH RAILWAY STATION appended (831/2056)
# HAMPTON COURT RAILWAY STATION appended (832/2056)
# HAMPTON IN ARDEN RAILWAY STATION appended (833/2056)
# HAMPTON RAILWAY STATION appended (834/2056)
# HAMPTON WICK RAILWAY STATION appended (835/2056)
# HAMWORTHY JUNCTION RAILWAY STATION appended (836/2056)
# HANBOROUGH RAILWAY STATION appended (837/2056)
# HANDFORTH RAILWAY STATION appended (838/2056)
# HANWELL RAILWAY STATION appended (839/2056)
# HAPTON RAILWAY STATION appended (840/2056)
# HARLECH RAILWAY STATION appended (841/2056)
# HARLESDEN RAILWAY STATION appended (842/2056)
# HARLING ROAD RAILWAY STATION appended (843/2056)
# HARLINGTON RAILWAY STATION appended (844/2056)
# HARLOW MILL RAILWAY STATION appended (845/2056)
# HARLOW TOWN RAILWAY STATION appended (846/2056)
# HAROLD WOOD RAILWAY STATION appended (847/2056)
# HARPENDEN CENTRAL RAILWAY STATION appended (848/2056)
# HARRIETSHAM RAILWAY STATION appended (849/2056)
# HARRINGAY RAILWAY STATION appended (850/2056)
# HARROGATE RAILWAY STATION appended (851/2056)
# HARTFORD RAILWAY STATION appended (852/2056)
# HARTLEPOOL RAILWAY STATION appended (853/2056)
# HARTWOOD RAILWAY STATION appended (854/2056)
# HARWICH INTERNATIONAL RAILWAY STATION appended (855/2056)
# HARWICH TOWN RAILWAY STATION appended (856/2056)
# HASLEMERE RAILWAY STATION appended (857/2056)
# HASSOCKS RAILWAY STATION appended (858/2056)
# HASTINGS RAILWAY STATION appended (859/2056)
# HATFIELD PEVEREL RAILWAY STATION appended (860/2056)
# HATFIELD RAILWAY STATION appended (861/2056)
# HATTERSLEY RAILWAY STATION appended (862/2056)
# HATTON RAILWAY STATION appended (863/2056)
# HAVANT RAILWAY STATION appended (864/2056)
# HAVERFORDWEST RAILWAY STATION appended (865/2056)
# HAWARDEN BRIDGE RAILWAY STATION appended (866/2056)
# HAWARDEN RAILWAY STATION appended (867/2056)
# HAWKHEAD RAILWAY STATION appended (868/2056)
# HAYDONS ROAD RAILWAY STATION appended (869/2056)
# HAYES (KENT) RAILWAY STATION appended (870/2056)
# HAYLE RAILWAY STATION appended (871/2056)
# HAYMARKET RAILWAY STATION appended (872/2056)
# HAYWARDS HEATH RAILWAY STATION appended (873/2056)
# HAZEL GROVE RAILWAY STATION appended (874/2056)
# HEADCORN RAILWAY STATION appended (875/2056)
# HEADINGLEY RAILWAY STATION appended (876/2056)
# HEALD GREEN RAILWAY STATION appended (877/2056)
# HEALING RAILWAY STATION appended (878/2056)
# HEATH HIGH LEVEL RAILWAY STATION appended (879/2056)
# HEATH LOW LEVEL RAILWAY STATION appended (880/2056)
# HEATHROW EXPRESS TERMINAL 1 2 3 RAILWAY STATION appended (881/2056)
# HEATHROW EXPRESS TERMINAL 4 RAILWAY STATION appended (882/2056)
# HEATHROW EXPRESS TERMINAL 5 RAILWAY STATION appended (883/2056)
# HEATON CHAPEL RAILWAY STATION appended (884/2056)
# HEDGE END RAILWAY STATION appended (885/2056)
# HEDNESFORD RAILWAY STATION appended (886/2056)
# HELENSBURGH CENTRAL RAILWAY STATION appended (887/2056)
# HELENSBURGH UPPER RAILWAY STATION appended (888/2056)
# HELLIFIELD RAILWAY STATION appended (889/2056)
# HELSBY RAILWAY STATION appended (890/2056)
# HEMEL HEMPSTEAD RAILWAY STATION appended (891/2056)
# HENDON RAILWAY STATION appended (892/2056)
# HENGOED RAILWAY STATION appended (893/2056)
# HENLEY ON THAMES RAILWAY STATION appended (894/2056)
# HENLEY-IN-ARDEN RAILWAY STATION appended (895/2056)
# HEREFORD RAILWAY STATION appended (896/2056)
# HERNE BAY RAILWAY STATION appended (897/2056)
# HERNE HILL RAILWAY STATION appended (898/2056)
# HERSHAM RAILWAY STATION appended (899/2056)
# HERTFORD EAST RAILWAY STATION appended (900/2056)
# HERTFORD NORTH RAILWAY STATION appended (901/2056)
# HESSLE RAILWAY STATION appended (902/2056)
# HESWALL RAILWAY STATION appended (903/2056)
# HEWORTH RAILWAY STATION appended (904/2056)
# HEXHAM RAILWAY STATION appended (905/2056)
# HEYFORD RAILWAY STATION appended (906/2056)
# HIGH BROOMS RAILWAY STATION appended (907/2056)
# HIGH WYCOMBE RAILWAY STATION appended (908/2056)
# HIGHAM RAILWAY STATION appended (909/2056)
# HIGHAMS PARK RAILWAY STATION appended (910/2056)
# HIGHBRIDGE AND BURNHAM RAILWAY STATION appended (911/2056)
# HIGHBURY AND ISLINGTON RAILWAY STATION appended (912/2056)
# HIGHTOWN RAILWAY STATION appended (913/2056)
# HILDENBOROUGH RAILWAY STATION appended (914/2056)
# HILLFOOT RAILWAY STATION appended (915/2056)
# HILLINGTON EAST RAILWAY STATION appended (916/2056)
# HILLINGTON WEST RAILWAY STATION appended (917/2056)
# HILLSIDE RAILWAY STATION appended (918/2056)
# HILSEA RAILWAY STATION appended (919/2056)
# HINCHLEY WOOD RAILWAY STATION appended (920/2056)
# HINCKLEY RAILWAY STATION appended (921/2056)
# HINDLEY RAILWAY STATION appended (922/2056)
# HINTON ADMIRAL RAILWAY STATION appended (923/2056)
# HITCHIN RAILWAY STATION appended (924/2056)
# HOCKLEY RAILWAY STATION appended (925/2056)
# HOLLINGBOURNE RAILWAY STATION appended (926/2056)
# HOLMES CHAPEL RAILWAY STATION appended (927/2056)
# HOLMWOOD RAILWAY STATION appended (928/2056)
# HOLTON HEATH RAILWAY STATION appended (929/2056)
# HOLYHEAD RAILWAY STATION appended (930/2056)
# HOLYTOWN RAILWAY STATION appended (931/2056)
# HONEYBOURNE RAILWAY STATION appended (932/2056)
# HONITON RAILWAY STATION appended (933/2056)
# HONOR OAK RAILWAY STATION appended (934/2056)
# HOOK RAILWAY STATION appended (935/2056)
# HOOTON RAILWAY STATION appended (936/2056)
# HOPE RAILWAY STATION appended (937/2056)
# HORDEN RAILWAY STATION appended (938/2056)
# HORLEY RAILWAY STATION appended (939/2056)
# HORNBEAM PARK RAILWAY STATION appended (940/2056)
# HORNSEY RAILWAY STATION appended (941/2056)
# HORSFORTH RAILWAY STATION appended (942/2056)
# HORSHAM RAILWAY STATION appended (943/2056)
# HORSLEY RAILWAY STATION appended (944/2056)
# HORWICH PARKWAY RAILWAY STATION appended (945/2056)
# HOUGH GREEN RAILWAY STATION appended (946/2056)
# HOUNSLOW RAILWAY STATION appended (947/2056)
# HOVE RAILWAY STATION appended (948/2056)
# HOVETON AND WROXHAM RAILWAY STATION appended (949/2056)
# HOW WOOD RAILWAY STATION appended (950/2056)
# HOWDEN RAILWAY STATION appended (951/2056)
# HOWWOOD RAILWAY STATION appended (952/2056)
# HOYLAKE RAILWAY STATION appended (953/2056)
# HUCKNALL RAILWAY STATION appended (954/2056)
# HUDDERSFIELD RAILWAY STATION appended (955/2056)
# HULL RAILWAY STATION appended (956/2056)
# HUMPHREY PARK RAILWAY STATION appended (957/2056)
# HUNCOAT RAILWAY STATION appended (958/2056)
# HUNGERFORD RAILWAY STATION appended (959/2056)
# HUNTINGDON RAILWAY STATION appended (960/2056)
# HUNTS CROSS RAILWAY STATION appended (961/2056)
# HURST GREEN RAILWAY STATION appended (962/2056)
# HUTTON CRANSWICK RAILWAY STATION appended (963/2056)
# HYDE NORTH RAILWAY STATION appended (964/2056)
# HYNDLAND RAILWAY STATION appended (965/2056)
# HYTHE RAILWAY STATION appended (966/2056)
# IFIELD RAILWAY STATION appended (967/2056)
# ILFORD RAILWAY STATION appended (968/2056)
# ILKESTON RAILWAY STATION appended (969/2056)
# ILKLEY RAILWAY STATION appended (970/2056)
# INCE AND ELTON RAILWAY STATION appended (971/2056)
# INCE RAILWAY STATION appended (972/2056)
# INGATESTONE RAILWAY STATION appended (973/2056)
# INSCH RAILWAY STATION appended (974/2056)
# INVERKEITHING RAILWAY STATION appended (975/2056)
# INVERNESS RAILWAY STATION appended (976/2056)
# INVERURIE RAILWAY STATION appended (977/2056)
# IPSWICH RAILWAY STATION appended (978/2056)
# IRLAM RAILWAY STATION appended (979/2056)
# IRVINE RAILWAY STATION appended (980/2056)
# ISLEWORTH RAILWAY STATION appended (981/2056)
# ISLIP RAILWAY STATION appended (982/2056)
# IVER RAILWAY STATION appended (983/2056)
# JEWELLERY QUARTER RAILWAY STATION appended (984/2056)
# JOHNSTONE RAILWAY STATION appended (985/2056)
# JORDANHILL RAILWAY STATION appended (986/2056)
# KEARSLEY RAILWAY STATION appended (987/2056)
# KEARSNEY RAILWAY STATION appended (988/2056)
# KEIGHLEY RAILWAY STATION appended (989/2056)
# KELVEDON RAILWAY STATION appended (990/2056)
# KELVINDALE RAILWAY STATION appended (991/2056)
# KEMBLE RAILWAY STATION appended (992/2056)
# KEMPSTON HARDWICK RAILWAY STATION appended (993/2056)
# KEMPTON PARK RAILWAY STATION appended (994/2056)
# KEMSLEY RAILWAY STATION appended (995/2056)
# KENDAL RAILWAY STATION appended (996/2056)
# KENILWORTH RAILWAY STATION appended (997/2056)
# KENLEY RAILWAY STATION appended (998/2056)
# KENNISHEAD RAILWAY STATION appended (999/2056)
# KENSAL GREEN RAILWAY STATION appended (1000/2056)
# KENSINGTON OLYMPIA RAILWAY STATION appended (1001/2056)
# KENT HOUSE RAILWAY STATION appended (1002/2056)
# KENTISH TOWN RAILWAY STATION appended (1003/2056)
# KENTISH TOWN WEST RAILWAY STATION appended (1004/2056)
# KENTON RAILWAY STATION appended (1005/2056)
# KETTERING RAILWAY STATION appended (1006/2056)
# KEW BRIDGE RAILWAY STATION appended (1007/2056)
# KEYNSHAM RAILWAY STATION appended (1008/2056)
# KIDBROOKE RAILWAY STATION appended (1009/2056)
# KIDDERMINSTER RAILWAY STATION appended (1010/2056)
# KIDSGROVE CENTRAL RAILWAY STATION appended (1011/2056)
# ...
# STRATFORD RAILWAY STATION appended (1731/2056)
# STRATFORD-UPON-AVON PARKWAY RAILWAY STATION appended (1732/2056)
# STRATFORD-UPON-AVON RAILWAY STATION appended (1733/2056)
# STRAWBERRY HILL RAILWAY STATION appended (1734/2056)
# STREATHAM COMMON RAILWAY STATION appended (1735/2056)
# STREATHAM HILL RAILWAY STATION appended (1736/2056)
# STREATHAM RAILWAY STATION appended (1737/2056)
# STROOD RAILWAY STATION appended (1738/2056)
# STROUD RAILWAY STATION appended (1739/2056)
# STURRY RAILWAY STATION appended (1740/2056)
# STYAL RAILWAY STATION appended (1741/2056)
# SUDBURY & HARROW ROAD RAILWAY STATION appended (1742/2056)
# SUDBURY HILL HARROW RAILWAY STATION appended (1743/2056)
# SUDBURY RAILWAY STATION appended (1744/2056)
# SUMMERSTON RAILWAY STATION appended (1745/2056)
# SUNBURY RAILWAY STATION appended (1746/2056)
# SUNDERLAND RAILWAY STATION appended (1747/2056)
# SUNDRIDGE PARK RAILWAY STATION appended (1748/2056)
# SUNNINGDALE RAILWAY STATION appended (1749/2056)
# SUNNYMEADS RAILWAY STATION appended (1750/2056)
# SURBITON RAILWAY STATION appended (1751/2056)
# SURREY QUAYS RAILWAY STATION appended (1752/2056)
# SUTTON (SURREY) RAILWAY STATION appended (1753/2056)
# SUTTON COLDFIELD RAILWAY STATION appended (1754/2056)
# SUTTON COMMON RAILWAY STATION appended (1755/2056)
# SUTTON PARKWAY RAILWAY STATION appended (1756/2056)
# SWALE RAILWAY STATION appended (1757/2056)
# SWANLEY RAILWAY STATION appended (1758/2056)
# SWANSCOMBE RAILWAY STATION appended (1759/2056)
# SWANSEA RAILWAY STATION appended (1760/2056)
# SWANWICK RAILWAY STATION appended (1761/2056)
# SWAY RAILWAY STATION appended (1762/2056)
# SWAYTHLING RAILWAY STATION appended (1763/2056)
# SWINDERBY RAILWAY STATION appended (1764/2056)
# SWINDON RAILWAY STATION appended (1765/2056)
# SWINESHEAD RAILWAY STATION appended (1766/2056)
# SWINTON RAILWAY STATION appended (1767/2056)
# SYDENHAM HILL RAILWAY STATION appended (1768/2056)
# SYDENHAM RAILWAY STATION appended (1769/2056)
# SYON LANE RAILWAY STATION appended (1770/2056)
# SYSTON RAILWAY STATION appended (1771/2056)
# TADWORTH RAILWAY STATION appended (1772/2056)
# TAFFS WELL RAILWAY STATION appended (1773/2056)
# TAME BRIDGE PARKWAY RAILWAY STATION appended (1774/2056)
# TAMWORTH RAILWAY STATION appended (1775/2056)
# TAPLOW RAILWAY STATION appended (1776/2056)
# TATTENHAM CORNER RAILWAY STATION appended (1777/2056)
# TAUNTON RAILWAY STATION appended (1778/2056)
# TAXI RANK SOUTH OF SHOREHAM BY SEA RAILWAY STATION appended (1779/2056)
# TAYNUILT RAILWAY STATION appended (1780/2056)
# TEDDINGTON RAILWAY STATION appended (1781/2056)
# TEIGNMOUTH RAILWAY STATION appended (1782/2056)
# TELFORD CENTRAL RAILWAY STATION appended (1783/2056)
# TENBY RAILWAY STATION appended (1784/2056)
# TEYNHAM RAILWAY STATION appended (1785/2056)
# THAMES DITTON RAILWAY STATION appended (1786/2056)
# THATCHAM RAILWAY STATION appended (1787/2056)
# THATTO HEATH RAILWAY STATION appended (1788/2056)
# THE HAWTHORNS RAILWAY STATION appended (1789/2056)
# THE LAKES RAILWAY STATION appended (1790/2056)
# THE RAILWAY STATION appended (1791/2056)
# THEALE RAILWAY STATION appended (1792/2056)
# THEOBALDS GROVE RAILWAY STATION appended (1793/2056)
# THETFORD RAILWAY STATION appended (1794/2056)
# THIRSK RAILWAY STATION appended (1795/2056)
# THORNABY RAILWAY STATION appended (1796/2056)
# THORNE NORTH RAILWAY STATION appended (1797/2056)
# THORNE SOUTH RAILWAY STATION appended (1798/2056)
# THORNLIEBANK RAILWAY STATION appended (1799/2056)
# THORNTON HEATH RAILWAY STATION appended (1800/2056)
# THORNTONHALL RAILWAY STATION appended (1801/2056)
# THORPE BAY RAILWAY STATION appended (1802/2056)
# THORPE LE SOKEN RAILWAY STATION appended (1803/2056)
# THREE BRIDGES RAILWAY STATION appended (1804/2056)
# THURGARTON RAILWAY STATION appended (1805/2056)
# THURNSCOE RAILWAY STATION appended (1806/2056)
# THURSTON RAILWAY STATION appended (1807/2056)
# TILBURY TOWN RAILWAY STATION appended (1808/2056)
# TILE HILL RAILWAY STATION appended (1809/2056)
# TILEHURST RAILWAY STATION appended (1810/2056)
# TIPTON RAILWAY STATION appended (1811/2056)
# TIRPHIL RAILWAY STATION appended (1812/2056)
# TISBURY RAILWAY STATION appended (1813/2056)
# TIVERTON PARKWAY RAILWAY STATION appended (1814/2056)
# TODMORDEN RAILWAY STATION appended (1815/2056)
# TOLWORTH RAILWAY STATION appended (1816/2056)
# TON PENTRE RAILWAY STATION appended (1817/2056)
# TONBRIDGE RAILWAY STATION appended (1818/2056)
# TONDU RAILWAY STATION appended (1819/2056)
# TONYPANDY RAILWAY STATION appended (1820/2056)
# TOOTING RAILWAY STATION appended (1821/2056)
# TORRE RAILWAY STATION appended (1822/2056)
# TOTNES RAILWAY STATION appended (1823/2056)
# TOTTON RAILWAY STATION appended (1824/2056)
# TOWER GATEWAY DOCKLANDS LIGHT RAILWAY STATION appended (1825/2056)
# TOWN GREEN RAILWAY STATION appended (1826/2056)
# TRAFFORD PARK RAILWAY STATION appended (1827/2056)
# TREFOREST ESTATE RAILWAY STATION appended (1828/2056)
# TREFOREST RAILWAY STATION appended (1829/2056)
# TREHAFOD RAILWAY STATION appended (1830/2056)
# TREHERBERT RAILWAY STATION appended (1831/2056)
# TREORCHY RAILWAY STATION appended (1832/2056)
# TRIMLEY RAILWAY STATION appended (1833/2056)
# TRING RAILWAY STATION appended (1834/2056)
# TROEDYRHIW RAILWAY STATION appended (1835/2056)
# TROON RAILWAY STATION appended (1836/2056)
# TROWBRIDGE RAILWAY STATION appended (1837/2056)
# TRURO RAILWAY STATION appended (1838/2056)
# TULSE HILL RAILWAY STATION appended (1839/2056)
# TUNBRIDGE WELLS RAILWAY STATION appended (1840/2056)
# TURKEY STREET RAILWAY STATION appended (1841/2056)
# TUTBURY AND HATTON RAILWAY STATION appended (1842/2056)
# TWICKENHAM RAILWAY STATION appended (1843/2056)
# TWYFORD RAILWAY STATION appended (1844/2056)
# TY GLAS RAILWAY STATION appended (1845/2056)
# TYSELEY RAILWAY STATION appended (1846/2056)
# TYWYN RAILWAY STATION appended (1847/2056)
# UCKFIELD RAILWAY STATION appended (1848/2056)
# UDDINGSTON RAILWAY STATION appended (1849/2056)
# ULLESKELF RAILWAY STATION appended (1850/2056)
# ULVERSTON RAILWAY STATION appended (1851/2056)
# UNIVERSITY RAILWAY STATION appended (1852/2056)
# UPHALL RAILWAY STATION appended (1853/2056)
# UPHOLLAND RAILWAY STATION appended (1854/2056)
# UPMINSTER RAILWAY STATION appended (1855/2056)
# UPPER HALLIFORD RAILWAY STATION appended (1856/2056)
# UPPER WARLINGHAM RAILWAY STATION appended (1857/2056)
# UPTON PARK RAILWAY STATION appended (1858/2056)
# UPTON RAILWAY STATION appended (1859/2056)
# UPWEY RAILWAY STATION appended (1860/2056)
# URMSTON RAILWAY STATION appended (1861/2056)
# UTTOXETER RAILWAY STATION appended (1862/2056)
# VAUXHALL RAILWAY STATION appended (1863/2056)
# VICTORIA RAILWAY STATION appended (1864/2056)
# VIRGINIA WATER RAILWAY STATION appended (1865/2056)
# WADDON RAILWAY STATION appended (1866/2056)
# WADHURST RAILWAY STATION appended (1867/2056)
# WAINFLEET RAILWAY STATION appended (1868/2056)
# WAKEFIELD KIRKGATE RAILWAY STATION appended (1869/2056)
# WAKEFIELD WESTGATE RAILWAY STATION appended (1870/2056)
# WALKDEN RAILWAY STATION appended (1871/2056)
# WALLASEY GROVE ROAD RAILWAY STATION appended (1872/2056)
# WALLASEY VILLAGE RAILWAY STATION appended (1873/2056)
# WALLINGTON RAILWAY STATION appended (1874/2056)
# WALLYFORD RAILWAY STATION appended (1875/2056)
# WALMER RAILWAY STATION appended (1876/2056)
# WALSALL RAILWAY STATION appended (1877/2056)
# WALTHAM CROSS RAILWAY STATION appended (1878/2056)
# WALTHAMSTOW QUEENS ROAD RAILWAY STATION appended (1879/2056)
# WALTON ON THAMES RAILWAY STATION appended (1880/2056)
# WALTON RAILWAY STATION appended (1881/2056)
# WANBOROUGH RAILWAY STATION appended (1882/2056)
# WANDSWORTH COMMON RAILWAY STATION appended (1883/2056)
# WANDSWORTH ROAD RAILWAY STATION appended (1884/2056)
# WANDSWORTH TOWN RAILWAY STATION appended (1885/2056)
# WAPPING RAILWAY STATION appended (1886/2056)
# WARBLINGTON RAILWAY STATION appended (1887/2056)
# WARE RAILWAY STATION appended (1888/2056)
# WAREHAM RAILWAY STATION appended (1889/2056)
# WARGRAVE RAILWAY STATION appended (1890/2056)
# WARMINSTER RAILWAY STATION appended (1891/2056)
# WARRINGTON BANK QUAY RAILWAY STATION appended (1892/2056)
# WARRINGTON CENTRAL RAILWAY STATION appended (1893/2056)
# WARRINGTON WEST RAILWAY STATION appended (1894/2056)
# WARWICK PARKWAY RAILWAY STATION appended (1895/2056)
# WARWICK RAILWAY STATION appended (1896/2056)
# WATER ORTON RAILWAY STATION appended (1897/2056)
# WATERBEACH RAILWAY STATION appended (1898/2056)
# WATERLOO (MERSEYSIDE) RAILWAY STATION appended (1899/2056)
# WATERLOO EAST RAILWAY STATION appended (1900/2056)
# WATERLOO RAILWAY STATION appended (1901/2056)
# WATFORD JUNCTION RAILWAY STATION appended (1902/2056)
# WATFORD NORTH RAILWAY STATION appended (1903/2056)
# WATLINGTON RAILWAY STATION appended (1904/2056)
# WATTON AT STONE RAILWAY STATION appended (1905/2056)
# WAUN GRON PARK RAILWAY STATION appended (1906/2056)
# WAVERTREE TECHNOLOGY PARK RAILWAY STATION appended (1907/2056)
# WEELEY RAILWAY STATION appended (1908/2056)
# WELHAM GREEN RAILWAY STATION appended (1909/2056)
# WELLING RAILWAY STATION appended (1910/2056)
# WELLINGBOROUGH RAILWAY STATION appended (1911/2056)
# WELLINGTON RAILWAY STATION appended (1912/2056)
# WELWYN GARDEN CITY RAILWAY STATION appended (1913/2056)
# WELWYN NORTH RAILWAY STATION appended (1914/2056)
# WEM RAILWAY STATION appended (1915/2056)
# WEMBLEY CENTRAL RAILWAY STATION appended (1916/2056)
# WEMBLEY STADIUM RAILWAY STATION appended (1917/2056)
# WEMYSS BAY RAILWAY STATION appended (1918/2056)
# WENDOVER RAILWAY STATION appended (1919/2056)
# WEST BROMPTON UNDERGROUND AND RAILWAY STATION appended (1920/2056)
# WEST BYFLEET RAILWAY STATION appended (1921/2056)
# WEST CALDER RAILWAY STATION appended (1922/2056)
# WEST CROYDON RAILWAY STATION appended (1923/2056)
# WEST DRAYTON RAILWAY STATION appended (1924/2056)
# WEST DULWICH RAILWAY STATION appended (1925/2056)
# WEST EALING RAILWAY STATION appended (1926/2056)
# WEST HAM RAILWAY STATION appended (1927/2056)
# WEST HAMPSTEAD RAILWAY STATION appended (1928/2056)
# WEST HORNDON RAILWAY STATION appended (1929/2056)
# WEST KIRBY RAILWAY STATION appended (1930/2056)
# WEST MALLING RAILWAY STATION appended (1931/2056)
# WEST NORWOOD RAILWAY STATION appended (1932/2056)
# WEST RUISLIP RAILWAY STATION appended (1933/2056)
# WEST RUNTON RAILWAY STATION appended (1934/2056)
# WEST ST LEONARDS RAILWAY STATION appended (1935/2056)
# WEST SUTTON RAILWAY STATION appended (1936/2056)
# WEST WICKHAM RAILWAY STATION appended (1937/2056)
# WEST WORTHING RAILWAY STATION appended (1938/2056)
# WESTBURY RAILWAY STATION appended (1939/2056)
# WESTCLIFF ON SEA RAILWAY STATION appended (1940/2056)
# WESTCOMBE PARK RAILWAY STATION appended (1941/2056)
# WESTENHANGER RAILWAY STATION appended (1942/2056)
# WESTER HAILES RAILWAY STATION appended (1943/2056)
# WESTERFIELD RAILWAY STATION appended (1944/2056)
# WESTERTON RAILWAY STATION appended (1945/2056)
# WESTGATE ON SEA RAILWAY STATION appended (1946/2056)
# WESTHOUGHTON RAILWAY STATION appended (1947/2056)
# WESTON MILTON RAILWAY STATION appended (1948/2056)
# WESTON SUPER MARE RAILWAY STATION appended (1949/2056)
# WETHERAL RAILWAY STATION appended (1950/2056)
# WEYBRIDGE RAILWAY STATION appended (1951/2056)
# WEYMOUTH RAILWAY STATION appended (1952/2056)
# WHALEY BRIDGE RAILWAY STATION appended (1953/2056)
# WHALLEY RAILWAY STATION appended (1954/2056)
# WHATSTANDWELL RAILWAY STATION appended (1955/2056)
# WHINHILL RAILWAY STATION appended (1956/2056)
# WHITBY RAILWAY STATION appended (1957/2056)
# WHITCHURCH (CARDIFF) RAILWAY STATION appended (1958/2056)
# WHITCHURCH (HANTS) RAILWAY STATION appended (1959/2056)
# WHITCHURCH (SHROPSHIRE) RAILWAY STATION appended (1960/2056)
# WHITE HART LANE RAILWAY STATION appended (1961/2056)
# WHITE NOTLEY RAILWAY STATION appended (1962/2056)
# WHITECRAIGS RAILWAY STATION appended (1963/2056)
# WHITEHAVEN RAILWAY STATION appended (1964/2056)
# WHITLAND RAILWAY STATION appended (1965/2056)
# WHITLOCKS END RAILWAY STATION appended (1966/2056)
# WHITSTABLE RAILWAY STATION appended (1967/2056)
# WHITTLESEA RAILWAY STATION appended (1968/2056)
# WHITTLESFORD PARKWAY RAILWAY STATION appended (1969/2056)
# WHITTON RAILWAY STATION appended (1970/2056)
# WHITWELL RAILWAY STATION appended (1971/2056)
# WHYTELEAFE RAILWAY STATION appended (1972/2056)
# WHYTELEAFE SOUTH RAILWAY STATION appended (1973/2056)
# WICKFORD RAILWAY STATION appended (1974/2056)
# WICKHAM MARKET RAILWAY STATION appended (1975/2056)
# WIDNES RAILWAY STATION appended (1976/2056)
# WIDNEY MANOR RAILWAY STATION appended (1977/2056)
# WIGAN NORTH WESTERN RAILWAY STATION appended (1978/2056)
# WIGTON RAILWAY STATION appended (1979/2056)
# WILDMILL RAILWAY STATION appended (1980/2056)
# WILLESDEN JUNCTION RAILWAY STATION appended (1981/2056)
# WILLIAMWOOD RAILWAY STATION appended (1982/2056)
# WILMCOTE RAILWAY STATION appended (1983/2056)
# WILMSLOW RAILWAY STATION appended (1984/2056)
# WILNECOTE RAILWAY STATION appended (1985/2056)
# WIMBLEDON CHASE RAILWAY STATION appended (1986/2056)
# WIMBLEDON RAILWAY STATION appended (1987/2056)
# WINCHELSEA RAILWAY STATION appended (1988/2056)
# WINCHESTER RAILWAY STATION appended (1989/2056)
# WINCHFIELD RAILWAY STATION appended (1990/2056)
# WINCHMORE HILL RAILWAY STATION appended (1991/2056)
# WINDERMERE RAILWAY STATION appended (1992/2056)
# WINDSOR AND ETON RIVERSIDE RAILWAY STATION appended (1993/2056)
# WINDSOR ROYAL RAILWAY STATION appended (1994/2056)
# WINNERSH RAILWAY STATION appended (1995/2056)
# WINNERSH TRIANGLE RAILWAY STATION appended (1996/2056)
# WINSFORD RAILWAY STATION appended (1997/2056)
# WITHAM RAILWAY STATION appended (1998/2056)
# WITLEY RAILWAY STATION appended (1999/2056)
# WITTON RAILWAY STATION appended (2000/2056)
# WIVELSFIELD RAILWAY STATION appended (2001/2056)
# WIVENHOE RAILWAY STATION appended (2002/2056)
# WOBURN SANDS RAILWAY STATION appended (2003/2056)
# WOKING RAILWAY STATION appended (2004/2056)
# WOKINGHAM RAILWAY STATION appended (2005/2056)
# WOLDINGHAM RAILWAY STATION appended (2006/2056)
# WOLVERHAMPTON RAILWAY STATION appended (2007/2056)
# WOLVERTON RAILWAY STATION appended (2008/2056)
# WOMBWELL RAILWAY STATION appended (2009/2056)
# WOOD STREET RAILWAY STATION appended (2010/2056)
# WOODBRIDGE RAILWAY STATION appended (2011/2056)
# WOODGRANGE PARK RAILWAY STATION appended (2012/2056)
# WOODHALL RAILWAY STATION appended (2013/2056)
# WOODHOUSE RAILWAY STATION appended (2014/2056)
# WOODLESFORD RAILWAY STATION appended (2015/2056)
# WOODLEY RAILWAY STATION appended (2016/2056)
# WOODMANSTERNE RAILWAY STATION appended (2017/2056)
# WOODSMOOR RAILWAY STATION appended (2018/2056)
# WOOL RAILWAY STATION appended (2019/2056)
# WOOLSTON RAILWAY STATION appended (2020/2056)
# WOOLWICH ARSENAL DOCKLANDS LIGHT RAILWAY STATION appended (2021/2056)
# WOOLWICH ARSENAL RAILWAY STATION appended (2022/2056)
# WOOLWICH DOCKYARD RAILWAY STATION appended (2023/2056)
# WOOTTON WAWEN RAILWAY STATION appended (2024/2056)
# WORCESTER PARK RAILWAY STATION appended (2025/2056)
# WORCESTER SHRUB HILL RAILWAY STATION appended (2026/2056)
# WORCESTERSHIRE PARKWAY RAILWAY STATION appended (2027/2056)
# WORKINGTON RAILWAY STATION appended (2028/2056)
# WORKSOP RAILWAY STATION appended (2029/2056)
# WORLE RAILWAY STATION appended (2030/2056)
# WORPLESDON RAILWAY STATION appended (2031/2056)
# WORSTEAD RAILWAY STATION appended (2032/2056)
# WORTHING RAILWAY STATION appended (2033/2056)
# WRABNESS RAILWAY STATION appended (2034/2056)
# WRAYSBURY RAILWAY STATION appended (2035/2056)
# WRENBURY RAILWAY STATION appended (2036/2056)
# WREXHAM CENTRAL RAILWAY STATION appended (2037/2056)
# WREXHAM GENERAL RAILWAY STATION appended (2038/2056)
# WYE RAILWAY STATION appended (2039/2056)
# WYLAM RAILWAY STATION appended (2040/2056)
# WYLDE GREEN RAILWAY STATION appended (2041/2056)
# WYMONDHAM RAILWAY STATION appended (2042/2056)
# WYTHALL RAILWAY STATION appended (2043/2056)
# YALDING RAILWAY STATION appended (2044/2056)
# YARDLEY WOOD RAILWAY STATION appended (2045/2056)
# YARM RAILWAY STATION appended (2046/2056)
# YATE RAILWAY STATION appended (2047/2056)
# YATTON RAILWAY STATION appended (2048/2056)
# YEOVIL PEN MILL RAILWAY STATION appended (2049/2056)
# YETMINSTER RAILWAY STATION appended (2050/2056)
# YNYSWEN RAILWAY STATION appended (2051/2056)
# YOKER RAILWAY STATION appended (2052/2056)
# YORK RAILWAY STATION appended (2053/2056)
# YORTON RAILWAY STATION appended (2054/2056)
# YSTRAD MYNACH RAILWAY STATION appended (2055/2056)
# YSTRAD RHONDDA RAILWAY STATION appended (2056/2056)

# %% [markdown]
# #### Final Database View

# %%
s_df.to_csv('data/exports/stations.csv')
s_df
# Out:
#                              station last recorded crime  score  count  \
# 0         ABBEY WOOD RAILWAY STATION           1/18/2022   5.37     75
# 1      ABBEYWOOD MOD RAILWAY STATION          12/14/2021   3.38     27
# 2               ABER RAILWAY STATION          12/19/2021   4.78      6
# 3          ABERCYNON RAILWAY STATION          11/19/2021   5.72      9
# 4           ABERDARE RAILWAY STATION          12/17/2021   5.35     11
# ...                              ...                 ...    ...    ...
# 2051           YOKER RAILWAY STATION           1/27/2022   4.78      5
# 2052            YORK RAILWAY STATION           1/31/2022   4.98    437
# 2053          YORTON RAILWAY STATION          10/13/2018   4.13      1
# 2054   YSTRAD MYNACH RAILWAY STATION           8/11/2021   5.23      9
# 2055  YSTRAD RHONDDA RAILWAY STATION          11/30/2021   4.22      9
#
#             lat       lng
# 0     51.490976  0.120832
# 1     51.507218 -0.127586
# 2     51.507218 -0.127586
# 3     51.507218 -0.127586
# 4     51.507218 -0.127586
# ...         ...       ...
# 2051  51.507218 -0.127586
# 2052  51.507218 -0.127586
# 2053  52.809132 -2.736207
# 2054  51.507218 -0.127586
# 2055  51.507218 -0.127586
#
# [2056 rows x 6 columns]

# %% [markdown]
# ### Connecting to a database
